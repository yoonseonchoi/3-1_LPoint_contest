# %%
import pandas as pd
import numpy as np

# %%
df4= pd.read_csv("LPOINT_BIG_COMP_04_PD_CLAC.csv", sep=',')
df4
# Out:
#         pd_c     pd_nm clac_hlv_nm clac_mcls_nm
# 0     PD0001        소파          가구         거실가구
# 1     PD0002   스툴/리빙의자          가구         거실가구
# 2     PD0003        탁자          가구         거실가구
# 3     PD0004   장식장/진열장          가구         거실가구
# 4     PD0005      기타가구          가구         기타가구
# ...      ...       ...         ...          ...
# 1928  PD1929      여성향수    화장품/뷰티케어           향수
# 1929  PD1930      남성향수    화장품/뷰티케어           향수
# 1930  PD1931    남녀공용향수    화장품/뷰티케어           향수
# 1931  PD1932    남성향수세트    화장품/뷰티케어           향수
# 1932  PD1933  남녀공용향수세트    화장품/뷰티케어           향수
#
# [1933 rows x 4 columns]

# %%
df4.isnull().sum()
# Out:
# pd_c            0
# pd_nm           0
# clac_hlv_nm     0
# clac_mcls_nm    0
# dtype: int64

# %%
pd.DataFrame(df4.groupby(df4['clac_hlv_nm']).size().sort_values(), columns = ['상품 대분류 별 상품 개수'])
# Out:
#              상품 대분류 별 상품 개수
# clac_hlv_nm
# 기타상품                      1
# 금융/보험서비스                  1
# 유아식품                      4
# 담배                        6
# 여행/레저서비스                  6
# 모바일                       6
# 기타(비상품)                   7
# 유제품                       9
# 상품권                      10
# 냉장/세탁가전                  12
# 생활/렌탈서비스                 13
# 컴퓨터                      14
# 병통조림                     14
# 공구/안전용품                  15
# 계절가전                     15
# 서적/음반/악기                 15
# 양곡                       15
# 헬스/피트니스                  15
# 커피/차                     20
# 냉동식품                     20
# 인테리어/조명                  21
# 시즌스포츠                    22
# 주류                       22
# 테넌트/음식점                  22
# 음료                       24
# 건강용품                     25
# 남성의류                     26
# 영상/음향가전                  27
# 세제/위생                    28
# 대용식                      29
# 여성의류                     29
# ...

# %%
pd.DataFrame(df4.groupby(df4['clac_mcls_nm']).size().sort_values(), columns = ['상품 중분류 별 상품 개수'])
# Out:
#               상품 중분류 별 상품 개수
# clac_mcls_nm
# 스케이트/썰매                    1
# 특수담배                       1
# 소모품                        1
# 기프트                        1
# 남아의류세트                     1
# ...                      ...
# 일반문구/사무용품                 17
# 잎채소                       18
# 주방가전                      18
# 국산과일                      19
# 어류                        20
#
# [349 rows x 1 columns]

# %%
df2 = pd.read_csv("p2_numeric.csv", sep=',')
df2
# Out:
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#          Unnamed: 0        cust        rct_no  chnl_dv  cop_c     br_c  \
# 0                 0  M430112881  A01000001113        1    101  A010039
# 1                 1  M646853852  A01000002265        1    101  A010025
# 2                 2  M430112881  A01000003148        1    101  A010039
# 3                 3  M430112881  A01000003148        1    101  A010039
# 4                 4  M430112881  A01000004946        1    101  A010039
# ...             ...         ...           ...      ...    ...      ...
# 4381738     4381738  M533286446  E06052119978        2    106      NaN
# 4381739     4381739  M533286446  E06052119978        2    106      NaN
# 4381740     4381740  M533286446  E06052119978        2    106      NaN
# ...

# %%
df24 = pd.merge(df2, df4, left_on = 'pd_c', right_on = 'pd_c', how = 'outer')
df24
# Out:
#          Unnamed: 0        cust        rct_no  chnl_dv  cop_c     br_c  \
# 0                 0  M430112881  A01000001113        1    101  A010039
# 1                 2  M430112881  A01000003148        1    101  A010039
# 2                 3  M430112881  A01000003148        1    101  A010039
# 3                 4  M430112881  A01000004946        1    101  A010039
# 4               147  M506355556  A01000107137        1    101  A010032
# ...             ...         ...           ...      ...    ...      ...
# 4381738     4378605  M696533418  E06045892016        2    106      NaN
# 4381739     4378606  M696533418  E06045892016        2    106      NaN
# 4381740     4378865  M111856694  E06045887405        2    106      NaN
# 4381741     4378866  M001808316  E06045891296        2    106      NaN
# 4381742     4379050  M475857646  E06046013307        2    106      NaN
#
#            pd_c  de_dt  de_hr    buy_am  buy_ct     pd_nm clac_hlv_nm  \
# ...

# %%
df24[df24['buy_ct']==100]
# Out:
#          Unnamed: 0        cust        rct_no  chnl_dv  cop_c     br_c  \
# 43052         90853  M282697479  A01064770920        1    101  A010037
# 43962        189324  M282697479  A01135093413        1    101  A010037
# 45048        305144  M282697479  A01217558938        1    101  A010037
# 46577        436519  M282697479  A01311491571        1    101  A010037
# 47470        515552  M282697479  A01368542746        1    101  A010037
# 96829        878493  M220751128  A02184946295        1    102  A020051
# 194306      2428648  M085041421  A02156839794        1    102  A020040
# 1125797     1723400  M037911118  A02349418443        1    102  A020112
# 1357921     2092035  M745864268  A02246841871        1    102  A020074
# 1590144     3993215  M035037103  A04004771811        1    104  A042600
# 2193885     4052020  M913531244  A04029022280        1    104  A043492
# 2415363     4374795  M927998831  E06047735952        2    106      NaN
# ...

# %%
print('상품명\n', df24['pd_nm'].mode())
print('상품 대분류\n',df24['clac_hlv_nm'].mode())
print('상품 중분류\n',df24['clac_mcls_nm'].mode())
# Out:
# 상품명
#  0    일반스낵
# dtype: object
# 상품 대분류
#  0    과자
# dtype: object
# 상품 중분류
#  0    스낵류
# dtype: object

# %%
df2.groupby('de_dt')['cust'].count()
# Out:
# de_dt
# 1    1188738
# 2    1171363
# 3    1076493
# 4     945149
# Name: cust, dtype: int64

# %%
df2.groupby('de_hr')['cust'].count()
# Out:
# de_hr
# 1      50943
# 2     506817
# 3    2306610
# 4    1517373
# Name: cust, dtype: int64

# %%
df1 = pd.read_csv("LPOINT_BIG_COMP_01_DEMO.csv", sep=',')

# %%
df124 = pd.merge(df1, df24, left_on = 'cust', right_on = 'cust', how = 'outer')

# %%
df124
# Out:
#                cust ma_fem_dv ages zon_hlv  Unnamed: 0        rct_no  chnl_dv  \
# 0        M000034966        여성  40대     Z07   1377582.0  A02357420240      1.0
# 1        M000034966        여성  40대     Z07   1377583.0  A02357421026      1.0
# 2        M000034966        여성  40대     Z07   2021903.0  A02358228482      1.0
# 3        M000034966        여성  40대     Z07     24063.0  A01016688590      1.0
# 4        M000034966        여성  40대     Z07     24061.0  A01016688590      1.0
# ...             ...       ...  ...     ...         ...           ...      ...
# 4384734  M999962961        여성  50대     Z17   3737230.0  A03073005783      1.0
# 4384735  M999962961        여성  50대     Z17   3060669.0  A02034710612      1.0
# 4384736  M999962961        여성  50대     Z17   3260021.0  A03071991818      1.0
# 4384737  M999962961        여성  50대     Z17   3228892.0  A03071935135      1.0
# 4384738  M999962961        여성  50대     Z17   3591713.0  A03072652674      1.0
#
# ...

# %%
df124.groupby('clac_hlv_nm')['ages'].agg(**{'most_common_value':lambda x:x.mode()}).reset_index()
# Out:
#    clac_hlv_nm most_common_value
# 0           가구               40대
# 1         건강식품               40대
# 2         건강용품               40대
# 3         건해산물               40대
# 4         계절가전               40대
# 5      공구/안전용품               40대
# 6           과일               40대
# 7           과자               40대
# 8     구기/필드스포츠               40대
# 9     금융/보험서비스               40대
# 10     기타(비상품)               40대
# 11        기타상품               40대
# 12        남성의류               40대
# 13        냉동식품               40대
# 14     냉장/세탁가전               40대
# 15        냉장식품               40대
# 16          담배               40대
# 17         대용식               40대
# 18         모바일               40대
# 19     문구/사무용품               40대
# 20        병통조림               40대
# 21         상품권               40대
# 22    생활/렌탈서비스               40대
# 23     생활/주방가전               40대
# 24    서적/음반/악기               40대
# 25       세제/위생               40대
# 26   속옷/양말/홈웨어               40대
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df2 = pd.read_csv("LPOINT_BIG_COMP_02_PDDE.csv", sep=',')
df3 = pd.read_csv("LPOINT_BIG_COMP_03_COP_U.csv", sep=',')
df6 = pd.read_csv("LPOINT_BIG_COMP_06_LPAY.csv", sep = ',')
# Out:
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ### 상품구매정보 데이터 셋 - 온라인 혹은 오프라인 구매 비율
# ##### 오프라인 이용 고객이 더 많음

# %%
df2.groupby('chnl_dv')['cust'].count().plot.bar(rot=0)
plt.gca().set_yticklabels(['{:,.0f}'.format(x) for x in plt.gca().get_yticks()])
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_8060/78458274.py:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:,.0f}'.format(x) for x in plt.gca().get_yticks()])

# %% [markdown]
# ### 제휴사이용정보 데이터 셋 - 온라인 혹은 오프라인 구매 비율
# ##### 오프라인 이용 고객이 더 많음

# %%
df3.groupby('chnl_dv')['cust'].count().plot.bar(rot=0)
plt.show()

# %% [markdown]
# ### L.Pay이용 데이터 셋 - 온라인 혹은 오프라인 구매 비율
# ##### 온라인 이용 고객이 더 많음

# %%
df6.groupby('chnl_dv')['cust'].count().plot.bar(rot=0)
plt.show()

# %% [markdown]
# ### 유통사 및 제휴사 별 L.Pay 이용 고객 비율
# ##### 비제휴사(L01)에서의 L.Pay 이용 고객 비율이 상당히 높음

# %%
df6_cop['users'] = df6_cop[0]
df6_cop = df6_cop.drop(0,axis=1)
colors = ['whitesmoke', 'whitesmoke', 'whitesmoke','whitesmoke','whitesmoke','whitesmoke','whitesmoke','whitesmoke','whitesmoke','whitesmoke','whitesmoke','whitesmoke', 'whitesmoke','gold']
explode = (0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,)
df6_cop['users'].plot(kind='pie', figsize=(7,7), autopct='%1.1f%%', colors=colors, fontsize=10, explode=explode)
plt.show()
